# %%
import pandas as pd

# %%
# Load the input data into a DataFrame
specific_df = pd.read_csv('biourja-efzrr-y7i38ed9-input.csv')
specific_df.columns = ['Plant_Name', 'Forecast', 'Capacity']

# %%
specific_df.head(10)
# Out:
#   Plant_Name  Forecast  Capacity
# 0         E1      45.4       100
# 1         E2      31.2       150
# 2         E3       8.5        50
# 3         E4      88.2       100
# 4         E5      98.4       150
# 5         E6     238.5       300
# 6         E7      66.8       100
# 7         E8     115.4       150
# 8         E9      74.0       100
# 9        E10     156.8       200

# %%
# Define the updated zones level forecasts
zones_forecasts = {
    'East': 2800,
    'North': 1500,
    'West': 2000,
    'South': 6500
}

# %%
# zones_df is the dataframe that contains zone and their corresponding zonal forecast
zones_df = pd.DataFrame(list(zones_forecasts.items()), columns=['zone', 'forecast'])

# %%
zones_df.head(5)
# Out:
#     zone  forecast
# 0   East      2800
# 1  North      1500
# 2   West      2000
# 3  South      6500

# %%
# Calculate the sum of all the forecasts
total = zones_df['forecast'].sum()

# Modify the "forecast" column with the formula
zones_df['forecast'] = (zones_df['forecast'] * 12000) / total

zones_df.head()
# Out:
#     zone  forecast
# 0   East   2625.00
# 1  North   1406.25
# 2   West   1875.00
# 3  South   6093.75

# %%
# Separating the individual wind farm forecasts zone wise 
east_dataframe = specific_df[specific_df['Plant_Name'].str.startswith('E')]
north_dataframe = specific_df[specific_df['Plant_Name'].str.startswith('N')]
west_dataframe = specific_df[specific_df['Plant_Name'].str.startswith('W')]
south_dataframe = specific_df[specific_df['Plant_Name'].str.startswith('S')]

# %%
# Adding a new column "Weight" to each of the dataframes
east_dataframe['Weight'] = east_dataframe['Forecast'] / east_dataframe['Capacity']
north_dataframe['Weight'] = north_dataframe['Forecast'] / north_dataframe['Capacity']
west_dataframe['Weight'] = west_dataframe['Forecast'] / west_dataframe['Capacity']
south_dataframe['Weight'] = south_dataframe['Forecast'] / south_dataframe['Capacity']
# Out:
# C:\Users\yuvraj\AppData\Local\Temp\ipykernel_13272\2072957644.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   east_dataframe['Weight'] = east_dataframe['Forecast'] / east_dataframe['Capacity']
# C:\Users\yuvraj\AppData\Local\Temp\ipykernel_13272\2072957644.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   north_dataframe['Weight'] = north_dataframe['Forecast'] / north_dataframe['Capacity']
# C:\Users\yuvraj\AppData\Local\Temp\ipykernel_13272\2072957644.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   west_dataframe['Weight'] = west_dataframe['Forecast'] / west_dataframe['Capacity']
# C:\Users\yuvraj\AppData\Local\Temp\ipykernel_13272\2072957644.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   south_dataframe['Weight'] = south_dataframe['Forecast'] / south_dataframe['Capacity']

# %%
east_dataframe.head(27)
# Out:
#    Plant_Name  Forecast  Capacity    Weight
# 0          E1      45.4       100  0.454000
# 1          E2      31.2       150  0.208000
# 2          E3       8.5        50  0.170000
# 3          E4      88.2       100  0.882000
# 4          E5      98.4       150  0.656000
# 5          E6     238.5       300  0.795000
# 6          E7      66.8       100  0.668000
# 7          E8     115.4       150  0.769333
# 8          E9      74.0       100  0.740000
# 9         E10     156.8       200  0.784000
# 10        E11     167.9       200  0.839500
# 11        E12     259.5       500  0.519000
# 12        E13      79.8       100  0.798000
# 13        E14      20.9       100  0.209000
# 14        E15     358.4       400  0.896000
# 15        E16      69.8       100  0.698000
# 16        E17      23.4       100  0.234000
# 17        E18       5.6        50  0.112000
# 18        E19     144.5       150  0.963333
# 19        E20     132.8       150  0.885333
# 20        E21      48.7        50  0.974000
# 21        E22       9.7        50  0.194000
# 22        E23      57.6       100  0.576000
# 23        E24     128.6       150  0.857333

# %%
# Calculating the summation of weight for each dataframe
e_weight_sum = east_dataframe['Weight'].sum()
n_weight_sum = north_dataframe['Weight'].sum()
w_weight_sum = west_dataframe['Weight'].sum()
s_weight_sum = south_dataframe['Weight'].sum()

# Calculating the new_forecast for each dataframe
east_dataframe['new_forecast'] = east_dataframe['Weight'] * (zones_df['forecast'][0] / e_weight_sum)
north_dataframe['new_forecast'] = north_dataframe['Weight'] * (zones_df['forecast'][1] / n_weight_sum)
west_dataframe['new_forecast'] = west_dataframe['Weight'] * (zones_df['forecast'][2] / w_weight_sum)
south_dataframe['new_forecast'] = south_dataframe['Weight'] * (zones_df['forecast'][3] / s_weight_sum)
# Out:
# C:\Users\yuvraj\AppData\Local\Temp\ipykernel_13272\1833253051.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   east_dataframe['new_forecast'] = east_dataframe['Weight'] * (zones_df['forecast'][0] / e_weight_sum)
# C:\Users\yuvraj\AppData\Local\Temp\ipykernel_13272\1833253051.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   north_dataframe['new_forecast'] = north_dataframe['Weight'] * (zones_df['forecast'][1] / n_weight_sum)
# C:\Users\yuvraj\AppData\Local\Temp\ipykernel_13272\1833253051.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   west_dataframe['new_forecast'] = west_dataframe['Weight'] * (zones_df['forecast'][2] / w_weight_sum)
# C:\Users\yuvraj\AppData\Local\Temp\ipykernel_13272\1833253051.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   south_dataframe['new_forecast'] = south_dataframe['Weight'] * (zones_df['forecast'][3] / s_weight_sum)

# %%
east_dataframe.head(27)
# Out:
#    Plant_Name  Forecast  Capacity    Weight  new_forecast
# 0          E1      45.4       100  0.454000     80.080859
# 1          E2      31.2       150  0.208000     36.689028
# 2          E3       8.5        50  0.170000     29.986225
# 3          E4      88.2       100  0.882000    155.575590
# 4          E5      98.4       150  0.656000    115.711550
# 5          E6     238.5       300  0.795000    140.229698
# 6          E7      66.8       100  0.668000    117.828225
# 7          E8     115.4       150  0.769333    135.702366
# 8          E9      74.0       100  0.740000    130.528273
# 9         E10     156.8       200  0.784000    138.289413
# 10        E11     167.9       200  0.839500    148.079034
# 11        E12     259.5       500  0.519000     91.546180
# 12        E13      79.8       100  0.798000    140.758867
# 13        E14      20.9       100  0.209000     36.865418
# 14        E15     358.4       400  0.896000    158.045044
# 15        E16      69.8       100  0.698000    123.119911
# 16        E17      23.4       100  0.234000     41.275157
# 17        E18       5.6        50  0.112000     19.755630
# 18        E19     144.5       150  0.963333    169.921941
# 19        E20     132.8       150  0.885333    156.163555
# 20        E21      48.7        50  0.974000    171.803429
# 21        E22       9.7        50  0.194000     34.219574
# 22        E23      57.6       100  0.576000    101.600385
# 23        E24     128.6       150  0.857333    151.224648

# %%
south_dataframe['Capacity'].sum()
# Out:
# 7950

# %%
# Defining a function to calculate the difference between new_forecast and Capacity and replacing negatives with zero
def calculate_difference(row):
    diff = row['new_forecast'] - row['Capacity']
    return max(0, diff)

# Appling the function to each dataframe
east_dataframe['diff_between_new_forecast_and_capacity'] = east_dataframe.apply(calculate_difference, axis=1)
north_dataframe['diff_between_new_forecast_and_capacity'] = north_dataframe.apply(calculate_difference, axis=1)
west_dataframe['diff_between_new_forecast_and_capacity'] = west_dataframe.apply(calculate_difference, axis=1)
south_dataframe['diff_between_new_forecast_and_capacity'] = south_dataframe.apply(calculate_difference, axis=1)
# Out:
# C:\Users\yuvraj\AppData\Local\Temp\ipykernel_13272\2539319358.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   east_dataframe['diff_between_new_forecast_and_capacity'] = east_dataframe.apply(calculate_difference, axis=1)
# C:\Users\yuvraj\AppData\Local\Temp\ipykernel_13272\2539319358.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   north_dataframe['diff_between_new_forecast_and_capacity'] = north_dataframe.apply(calculate_difference, axis=1)
# C:\Users\yuvraj\AppData\Local\Temp\ipykernel_13272\2539319358.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   west_dataframe['diff_between_new_forecast_and_capacity'] = west_dataframe.apply(calculate_difference, axis=1)
# C:\Users\yuvraj\AppData\Local\Temp\ipykernel_13272\2539319358.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   south_dataframe['diff_between_new_forecast_and_capacity'] = south_dataframe.apply(calculate_difference, axis=1)

# %%
east_dataframe
# Out:
#    Plant_Name  Forecast  Capacity    Weight  new_forecast  \
# 0          E1      45.4       100  0.454000     80.080859
# 1          E2      31.2       150  0.208000     36.689028
# 2          E3       8.5        50  0.170000     29.986225
# 3          E4      88.2       100  0.882000    155.575590
# 4          E5      98.4       150  0.656000    115.711550
# 5          E6     238.5       300  0.795000    140.229698
# 6          E7      66.8       100  0.668000    117.828225
# 7          E8     115.4       150  0.769333    135.702366
# 8          E9      74.0       100  0.740000    130.528273
# 9         E10     156.8       200  0.784000    138.289413
# 10        E11     167.9       200  0.839500    148.079034
# 11        E12     259.5       500  0.519000     91.546180
# 12        E13      79.8       100  0.798000    140.758867
# 13        E14      20.9       100  0.209000     36.865418
# 14        E15     358.4       400  0.896000    158.045044
# 15        E16      69.8       100  0.698000    123.119911
# 16        E17      23.4       100  0.234000     41.275157
# 17        E18       5.6        50  0.112000     19.755630
# 18        E19     144.5       150  0.963333    169.921941
# 19        E20     132.8       150  0.885333    156.163555
# 20        E21      48.7        50  0.974000    171.803429
# 21        E22       9.7        50  0.194000     34.219574
# 22        E23      57.6       100  0.576000    101.600385
# 23        E24     128.6       150  0.857333    151.224648
#
#     diff_between_new_forecast_and_capacity
# 0                                 0.000000
# 1                                 0.000000
# 2                                 0.000000
# 3                                55.575590
# 4                                 0.000000
# 5                                 0.000000
# 6                                17.828225
# 7                                 0.000000
# 8                                30.528273
# 9                                 0.000000
# 10                                0.000000
# 11                                0.000000
# 12                               40.758867
# 13                                0.000000
# 14                                0.000000
# 15                               23.119911
# 16                                0.000000
# 17                                0.000000
# 18                               19.921941
# 19                                6.163555
# 20                              121.803429
# 21                                0.000000
# 22                                1.600385
# 23                                1.224648

# %%
east_exceeded_forecast = east_dataframe['diff_between_new_forecast_and_capacity'].sum()
north_exceeded_forecast = north_dataframe['diff_between_new_forecast_and_capacity'].sum()
west_exceeded_forecast = west_dataframe['diff_between_new_forecast_and_capacity'].sum()
south_exceeded_forecast = south_dataframe['diff_between_new_forecast_and_capacity'].sum()

# %%
# For each of the zones we are calculating the sum of weights of wind farms being considered for distribution of exceeding new forecasts

# For 'East' dataframe
sum_weights_e_less_than_capacity = east_dataframe.loc[east_dataframe['new_forecast'] < east_dataframe['Capacity'], 'Weight'].sum()

# For 'North' dataframe
sum_weights_n_less_than_capacity = north_dataframe.loc[north_dataframe['new_forecast'] < north_dataframe['Capacity'], 'Weight'].sum()

# For 'West' dataframe
sum_weights_w_less_than_capacity = west_dataframe.loc[west_dataframe['new_forecast'] < west_dataframe['Capacity'], 'Weight'].sum()

# For 'South' dataframe
sum_weights_s_less_than_capacity = south_dataframe.loc[south_dataframe['new_forecast'] < south_dataframe['Capacity'], 'Weight'].sum()

# %%
east_dataframe['new_forecast'] = east_dataframe.apply(lambda row: row['new_forecast'] + (row['Weight'] * east_exceeded_forecast / sum_weights_e_less_than_capacity) if row['new_forecast'] < row['Capacity'] else row['Capacity'], axis=1)
# Out:
# C:\Users\yuvraj\AppData\Local\Temp\ipykernel_13272\2178656944.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   east_dataframe['new_forecast'] = east_dataframe.apply(lambda row: row['new_forecast'] + (row['Weight'] * east_exceeded_forecast / sum_weights_e_less_than_capacity) if row['new_forecast'] < row['Capacity'] else row['Capacity'], axis=1)

# %%
east_dataframe.head(27)
# Out:
#    Plant_Name  Forecast  Capacity    Weight  new_forecast  \
# 0          E1      45.4       100  0.454000    101.223227
# 1          E2      31.2       150  0.208000     46.375399
# 2          E3       8.5        50  0.170000     37.902970
# 3          E4      88.2       100  0.882000    100.000000
# 4          E5      98.4       150  0.656000    146.260874
# 5          E6     238.5       300  0.795000    177.252126
# 6          E7      66.8       100  0.668000    100.000000
# 7          E8     115.4       150  0.769333    171.529521
# 8          E9      74.0       100  0.740000    100.000000
# 9         E10     156.8       200  0.784000    174.799581
# 10        E11     167.9       200  0.839500    187.173786
# 11        E12     259.5       500  0.519000    115.715539
# 12        E13      79.8       100  0.798000    100.000000
# 13        E14      20.9       100  0.209000     46.598358
# 14        E15     358.4       400  0.896000    199.770950
# 15        E16      69.8       100  0.698000    100.000000
# 16        E17      23.4       100  0.234000     52.172324
# 17        E18       5.6        50  0.112000     24.971369
# 18        E19     144.5       150  0.963333    150.000000
# 19        E20     132.8       150  0.885333    150.000000
# 20        E21      48.7        50  0.974000     50.000000
# 21        E22       9.7        50  0.194000     43.253978
# 22        E23      57.6       100  0.576000    100.000000
# 23        E24     128.6       150  0.857333    150.000000
#
#     diff_between_new_forecast_and_capacity
# 0                                 0.000000
# 1                                 0.000000
# 2                                 0.000000
# 3                                55.575590
# 4                                 0.000000
# 5                                 0.000000
# 6                                17.828225
# 7                                 0.000000
# 8                                30.528273
# 9                                 0.000000
# 10                                0.000000
# 11                                0.000000
# 12                               40.758867
# 13                                0.000000
# 14                                0.000000
# 15                               23.119911
# 16                                0.000000
# 17                                0.000000
# 18                               19.921941
# 19                                6.163555
# 20                              121.803429
# 21                                0.000000
# 22                                1.600385
# 23                                1.224648

# %%
north_dataframe['new_forecast'] = north_dataframe.apply(lambda row: row['new_forecast'] + (row['Weight'] * north_exceeded_forecast / sum_weights_n_less_than_capacity) if row['new_forecast'] < row['Capacity'] else row['Capacity'], axis=1)
west_dataframe['new_forecast'] = west_dataframe.apply(lambda row: row['new_forecast'] + (row['Weight'] * west_exceeded_forecast / sum_weights_w_less_than_capacity) if row['new_forecast'] < row['Capacity'] else row['Capacity'], axis=1)
south_dataframe['new_forecast'] = south_dataframe.apply(lambda row: row['new_forecast'] + (row['Weight'] * south_exceeded_forecast / sum_weights_s_less_than_capacity) if row['new_forecast'] < row['Capacity'] else row['Capacity'], axis=1)
# Out:
# C:\Users\yuvraj\AppData\Local\Temp\ipykernel_13272\2226787471.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   north_dataframe['new_forecast'] = north_dataframe.apply(lambda row: row['new_forecast'] + (row['Weight'] * north_exceeded_forecast / sum_weights_n_less_than_capacity) if row['new_forecast'] < row['Capacity'] else row['Capacity'], axis=1)
# C:\Users\yuvraj\AppData\Local\Temp\ipykernel_13272\2226787471.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   west_dataframe['new_forecast'] = west_dataframe.apply(lambda row: row['new_forecast'] + (row['Weight'] * west_exceeded_forecast / sum_weights_w_less_than_capacity) if row['new_forecast'] < row['Capacity'] else row['Capacity'], axis=1)
# C:\Users\yuvraj\AppData\Local\Temp\ipykernel_13272\2226787471.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   south_dataframe['new_forecast'] = south_dataframe.apply(lambda row: row['new_forecast'] + (row['Weight'] * south_exceeded_forecast / sum_weights_s_less_than_capacity) if row['new_forecast'] < row['Capacity'] else row['Capacity'], axis=1)

# %%
# If new_forecast is greater than the capacity, we will apply the same process as applied above to distribute the exceeding weights.
east_dataframe['diff_between_new_forecast_and_capacity'] = east_dataframe.apply(calculate_difference, axis=1)
north_dataframe['diff_between_new_forecast_and_capacity'] = north_dataframe.apply(calculate_difference, axis=1)
west_dataframe['diff_between_new_forecast_and_capacity'] = west_dataframe.apply(calculate_difference, axis=1)
south_dataframe['diff_between_new_forecast_and_capacity'] = south_dataframe.apply(calculate_difference, axis=1)
# Out:
#   Cell In[22], line 1
#     .
#     ^
# SyntaxError: invalid syntax

# %%
east_dataframe.head(27)
# Out:
#    Plant_Name  Forecast  Capacity    Weight  new_forecast  \
# 0          E1      45.4       100  0.454000    101.223227
# 1          E2      31.2       150  0.208000     46.375399
# 2          E3       8.5        50  0.170000     37.902970
# 3          E4      88.2       100  0.882000    100.000000
# 4          E5      98.4       150  0.656000    146.260874
# 5          E6     238.5       300  0.795000    177.252126
# 6          E7      66.8       100  0.668000    100.000000
# 7          E8     115.4       150  0.769333    171.529521
# 8          E9      74.0       100  0.740000    100.000000
# 9         E10     156.8       200  0.784000    174.799581
# 10        E11     167.9       200  0.839500    187.173786
# 11        E12     259.5       500  0.519000    115.715539
# 12        E13      79.8       100  0.798000    100.000000
# 13        E14      20.9       100  0.209000     46.598358
# 14        E15     358.4       400  0.896000    199.770950
# 15        E16      69.8       100  0.698000    100.000000
# 16        E17      23.4       100  0.234000     52.172324
# 17        E18       5.6        50  0.112000     24.971369
# 18        E19     144.5       150  0.963333    150.000000
# 19        E20     132.8       150  0.885333    150.000000
# 20        E21      48.7        50  0.974000     50.000000
# 21        E22       9.7        50  0.194000     43.253978
# 22        E23      57.6       100  0.576000    100.000000
# 23        E24     128.6       150  0.857333    150.000000
#
#     diff_between_new_forecast_and_capacity
# 0                                 0.000000
# 1                                 0.000000
# 2                                 0.000000
# 3                                55.575590
# 4                                 0.000000
# 5                                 0.000000
# 6                                17.828225
# 7                                 0.000000
# 8                                30.528273
# 9                                 0.000000
# 10                                0.000000
# 11                                0.000000
# 12                               40.758867
# 13                                0.000000
# 14                                0.000000
# 15                               23.119911
# 16                                0.000000
# 17                                0.000000
# 18                               19.921941
# 19                                6.163555
# 20                              121.803429
# 21                                0.000000
# 22                                1.600385
# 23                                1.224648

# %%
east_exceeded_forecast = east_dataframe['diff_between_new_forecast_and_capacity'].sum()
north_exceeded_forecast = north_dataframe['diff_between_new_forecast_and_capacity'].sum()
west_exceeded_forecast = west_dataframe['diff_between_new_forecast_and_capacity'].sum()
south_exceeded_forecast = south_dataframe['diff_between_new_forecast_and_capacity'].sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 east_exceeded_forecast = east_individual_dataframe['diff_between_new_forecast_and_capacity'].sum()
#       2 north_exceeded_forecast = north_individual_dataframe['diff_between_new_forecast_and_capacity'].sum()
#       3 west_exceeded_forecast = west_individual_dataframe['diff_between_new_forecast_and_capacity'].sum()
#
# NameError: name 'east_individual_dataframe' is not defined

# %%
# For 'East' dataframe
sum_weights_e_less_than_capacity = east_dataframe.loc[east_dataframe['new_forecast'] < east_dataframe['Capacity'], 'Weight'].sum()

# For 'North' dataframe
sum_weights_n_less_than_capacity = north_dataframe.loc[north_dataframe['new_forecast'] < north_dataframe['Capacity'], 'Weight'].sum()

# For 'West' dataframe
sum_weights_w_less_than_capacity = west_dataframe.loc[west_dataframe['new_forecast'] < west_dataframe['Capacity'], 'Weight'].sum()

# For 'South' dataframe
sum_weights_s_less_than_capacity = south_dataframe.loc[south_dataframe['new_forecast'] < south_dataframe['Capacity'], 'Weight'].sum()

# %%
east_dataframe['new_forecast'] = east_dataframe.apply(lambda row: row['new_forecast'] + (row['Weight'] * east_exceeded_forecast / sum_weights_e_less_than_capacity) if row['new_forecast'] < row['Capacity'] else row['Capacity'], axis=1)
north_dataframe['new_forecast'] = north_dataframe.apply(lambda row: row['new_forecast'] + (row['Weight'] * north_exceeded_forecast / sum_weights_n_less_than_capacity) if row['new_forecast'] < row['Capacity'] else row['Capacity'], axis=1)
west_dataframe['new_forecast'] = west_dataframe.apply(lambda row: row['new_forecast'] + (row['Weight'] * west_exceeded_forecast / sum_weights_w_less_than_capacity) if row['new_forecast'] < row['Capacity'] else row['Capacity'], axis=1)
south_dataframe['new_forecast'] = south_dataframe.apply(lambda row: row['new_forecast'] + (row['Weight'] * south_exceeded_forecast / sum_weights_s_less_than_capacity) if row['new_forecast'] < row['Capacity'] else row['Capacity'], axis=1)
# Out:
# C:\Users\yuvraj\AppData\Local\Temp\ipykernel_13272\3611532249.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   east_dataframe['new_forecast'] = east_dataframe.apply(lambda row: row['new_forecast'] + (row['Weight'] * east_exceeded_forecast / sum_weights_e_less_than_capacity) if row['new_forecast'] < row['Capacity'] else row['Capacity'], axis=1)
# C:\Users\yuvraj\AppData\Local\Temp\ipykernel_13272\3611532249.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   north_dataframe['new_forecast'] = north_dataframe.apply(lambda row: row['new_forecast'] + (row['Weight'] * north_exceeded_forecast / sum_weights_n_less_than_capacity) if row['new_forecast'] < row['Capacity'] else row['Capacity'], axis=1)
# C:\Users\yuvraj\AppData\Local\Temp\ipykernel_13272\3611532249.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   west_dataframe['new_forecast'] = west_dataframe.apply(lambda row: row['new_forecast'] + (row['Weight'] * west_exceeded_forecast / sum_weights_w_less_than_capacity) if row['new_forecast'] < row['Capacity'] else row['Capacity'], axis=1)
# C:\Users\yuvraj\AppData\Local\Temp\ipykernel_13272\3611532249.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   south_dataframe['new_forecast'] = south_dataframe.apply(lambda row: row['new_forecast'] + (row['Weight'] * south_exceeded_forecast / sum_weights_s_less_than_capacity) if row['new_forecast'] < row['Capacity'] else row['Capacity'], axis=1)

# %%
east_dataframe['diff_between_new_forecast_and_capacity'] = east_dataframe.apply(calculate_difference, axis=1)
north_dataframe['diff_between_new_forecast_and_capacity'] = north_dataframe.apply(calculate_difference, axis=1)
west_dataframe['diff_between_new_forecast_and_capacity'] = west_dataframe.apply(calculate_difference, axis=1)
south_dataframe['diff_between_new_forecast_and_capacity'] = south_dataframe.apply(calculate_difference, axis=1)
# Out:
# C:\Users\yuvraj\AppData\Local\Temp\ipykernel_13272\2355148040.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   east_dataframe['diff_between_new_forecast_and_capacity'] = east_dataframe.apply(calculate_difference, axis=1)
# C:\Users\yuvraj\AppData\Local\Temp\ipykernel_13272\2355148040.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   north_dataframe['diff_between_new_forecast_and_capacity'] = north_dataframe.apply(calculate_difference, axis=1)
# C:\Users\yuvraj\AppData\Local\Temp\ipykernel_13272\2355148040.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   west_dataframe['diff_between_new_forecast_and_capacity'] = west_dataframe.apply(calculate_difference, axis=1)
# C:\Users\yuvraj\AppData\Local\Temp\ipykernel_13272\2355148040.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   south_dataframe['diff_between_new_forecast_and_capacity'] = south_dataframe.apply(calculate_difference, axis=1)

# %%
west_exceeded_forecast = west_dataframe['diff_between_new_forecast_and_capacity'].sum()
sum_weights_w_less_than_capacity = west_dataframe.loc[west_dataframe['new_forecast'] < west_dataframe['Capacity'], 'Weight'].sum()
west_dataframe['new_forecast'] = west_dataframe.apply(lambda row: row['new_forecast'] + (row['Weight'] * west_exceeded_forecast / sum_weights_w_less_than_capacity) if row['new_forecast'] < row['Capacity'] else row['Capacity'], axis=1)
# Out:
# C:\Users\yuvraj\AppData\Local\Temp\ipykernel_13272\2659718394.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   west_dataframe['new_forecast'] = west_dataframe.apply(lambda row: row['new_forecast'] + (row['Weight'] * west_exceeded_forecast / sum_weights_w_less_than_capacity) if row['new_forecast'] < row['Capacity'] else row['Capacity'], axis=1)

# %%
west_dataframe['diff_between_new_forecast_and_capacity'] = west_dataframe.apply(calculate_difference, axis=1)
# Out:
# C:\Users\yuvraj\AppData\Local\Temp\ipykernel_13272\1332792618.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   west_dataframe['diff_between_new_forecast_and_capacity'] = west_dataframe.apply(calculate_difference, axis=1)

# %%
# Merge the four dataframes into one
merged_dataframe = pd.concat([east_dataframe, north_dataframe, west_dataframe, south_dataframe])

# Select only the 'Plant_Name' and 'new_forecast' columns
merged_dataframe = merged_dataframe[['Plant_Name', 'new_forecast']]

# Rename the 'new_forecast' column to 'forecast'
merged_dataframe.rename(columns={'new_forecast': 'Forecast'}, inplace=True)

# Save the merged dataframe to a CSV file
merged_dataframe.to_csv('merged_data.csv', index=False)

# %%
merged_dataframe.head(100)
# Out:
#    Plant_Name    Forecast
# 0          E1  100.000000
# 1          E2   58.171564
# 2          E3   47.544067
# 3          E4  100.000000
# 4          E5  183.464165
# ..        ...         ...
# 95        S31  281.550938
# 96        S32  150.000000
# 97        S33  200.000000
# 98        S34   50.000000
# 99        S35  398.342848
#
# [100 rows x 2 columns]
